# %%
## Download the modules needed for the analysis below

from zipfile import ZipFile
import pandas as pd
import json
from datetime import datetime

# %%
## Set the path to import our file
# %cd "C:\Fitness\Cycling Data\Raw data"
# Out:
# C:\Fitness\Cycling Data\Raw data

# %%
#### Before I go any further, this step below borrows heavily from the link below and I have obviously adapted it for my use 
### case but credit must go where credit is due to Maksym Kozlenko and his amazing illustration of how to easily import and
### load your Google Timeline Location History data. Please see the link below 
### https://betterprogramming.pub/loading-location-history-places-from-google-timeline-into-pandas-and-csv-c26cb0ac5e89


# path to Google Location History takeout file
history_data_file = "takeout-20230915T180410Z-001.zip"

# store all places into this array
cycle_trips = []

# Import the zip file and unzip the Google Timeline location history JSON files
with ZipFile(history_data_file) as myzip:
    for file in myzip.filelist[:]:
        filename = file.filename

# We want to look for the "Semantic Location History" files that contains the cycling distance data that we want to analyse below
        if "Semantic Location History" in filename:
            # process all files in "Semantic Location History" directory
            history_json = json.load(myzip.open(filename))
            
            # We need to locate the timeline object within the JSON file that contains the cycling distance data
            for timeline_object in history_json["timelineObjects"]:   
             
 # The key timeline object is "activitySegment" and we set up an object which basically contains the data stored as a dictionary
                if "activitySegment" in timeline_object:
                    cycle_trips_json = timeline_object["activitySegment"]                 
                    
# skip records where there are missing values for distance and if Google cannot record a 'LOW','MEDIUM'.'HIGH' categorisation for
# your recorded activity      
                    if not "distance" in cycle_trips_json or not 'confidence' in cycle_trips_json:
                        continue

                    activity_data = {
                        'Activity_Type': cycle_trips_json['activities'][0]['activityType'],
                        "Activity_Type_probability": cycle_trips_json['activities'][0]['probability'],
                        "distance": cycle_trips_json['distance'],
                        "confidence": cycle_trips_json['confidence'],
                        "startTimestamp": cycle_trips_json["duration"]["startTimestamp"],
                        "endTimestamp": cycle_trips_json["duration"]["endTimestamp"],
                    }                    
                    cycle_trips.append(activity_data)

# %%
cycle_trips_df = pd.DataFrame(cycle_trips)

# %%
df = cycle_trips_df.copy()

# %%
df
# Out:
#                Activity_Type  Activity_Type_probability  distance  \
# 0                    CYCLING                      62.95      1131
# 1                    CYCLING                      82.46       944
# 2                    CYCLING                      82.52      1261
# 3                    CYCLING                      88.82      1133
# 4                    CYCLING                      69.85      2124
# ...                      ...                        ...       ...
# 10646                WALKING                       0.00      1101
# 10647  UNKNOWN_ACTIVITY_TYPE                       0.00      1828
# 10648                CYCLING                       0.00       613
# 10649             IN_VEHICLE                       0.00      3719
# 10650                CYCLING                       0.00      5595
#
#                confidence            startTimestamp              endTimestamp
# 0                  MEDIUM  2020-05-18T18:00:09.211Z  2020-05-18T18:16:18.919Z
# 1                    HIGH  2020-05-18T19:34:05.079Z  2020-05-18T19:44:14.080Z
# 2                    HIGH  2020-05-19T09:20:20.388Z  2020-05-19T10:07:08.805Z
# 3                    HIGH  2020-05-19T13:28:45.485Z  2020-05-19T13:49:58.977Z
# 4                  MEDIUM  2020-05-20T07:25:32.727Z  2020-05-20T08:14:30.274Z
# ...                   ...                       ...                       ...
# 10646                 LOW  2015-01-17T22:46:19.429Z  2015-01-19T10:37:09.002Z
# 10647  UNKNOWN_CONFIDENCE  2015-01-20T16:53:06.911Z  2015-01-21T20:26:28.553Z
# 10648                 LOW  2015-01-21T20:26:28.553Z  2015-01-21T20:28:28.625Z
# 10649                 LOW  2015-01-27T19:17:14.586Z  2015-01-27T21:04:03.619Z
# 10650                 LOW  2015-01-29T19:42:16.804Z  2015-01-31T16:56:54.871Z
#
# [10651 rows x 6 columns]

# %%
## This removes TZ info from the start/end Timestamp datetime columns and remove the nanoseconds 
df['startTimestamp'] = pd.to_datetime(df.startTimestamp).dt.tz_localize(None).dt.floor('S')
df['endTimestamp'] = pd.to_datetime(df.endTimestamp).dt.tz_localize(None).dt.floor('S')
df
# Out:
#                Activity_Type  Activity_Type_probability  distance  \
# 0                    CYCLING                      62.95      1131
# 1                    CYCLING                      82.46       944
# 2                    CYCLING                      82.52      1261
# 3                    CYCLING                      88.82      1133
# 4                    CYCLING                      69.85      2124
# ...                      ...                        ...       ...
# 10646                WALKING                       0.00      1101
# 10647  UNKNOWN_ACTIVITY_TYPE                       0.00      1828
# 10648                CYCLING                       0.00       613
# 10649             IN_VEHICLE                       0.00      3719
# 10650                CYCLING                       0.00      5595
#
#                confidence      startTimestamp        endTimestamp
# 0                  MEDIUM 2020-05-18 18:00:09 2020-05-18 18:16:18
# 1                    HIGH 2020-05-18 19:34:05 2020-05-18 19:44:14
# 2                    HIGH 2020-05-19 09:20:20 2020-05-19 10:07:08
# 3                    HIGH 2020-05-19 13:28:45 2020-05-19 13:49:58
# 4                  MEDIUM 2020-05-20 07:25:32 2020-05-20 08:14:30
# ...                   ...                 ...                 ...
# 10646                 LOW 2015-01-17 22:46:19 2015-01-19 10:37:09
# 10647  UNKNOWN_CONFIDENCE 2015-01-20 16:53:06 2015-01-21 20:26:28
# 10648                 LOW 2015-01-21 20:26:28 2015-01-21 20:28:28
# 10649                 LOW 2015-01-27 19:17:14 2015-01-27 21:04:03
# 10650                 LOW 2015-01-29 19:42:16 2015-01-31 16:56:54
#
# [10651 rows x 6 columns]

# %%
df['day'] = df['endTimestamp'].dt.day
df['month'] = df['endTimestamp'].dt.month
df['year'] = df['endTimestamp'].dt.year
df['date'] = df['endTimestamp'].dt.date
df['day_name'] = df['endTimestamp'].dt.day_name()

# %%
df
# Out:
#                Activity_Type  Activity_Type_probability  distance  \
# 0                    CYCLING                      62.95      1131
# 1                    CYCLING                      82.46       944
# 2                    CYCLING                      82.52      1261
# 3                    CYCLING                      88.82      1133
# 4                    CYCLING                      69.85      2124
# ...                      ...                        ...       ...
# 10646                WALKING                       0.00      1101
# 10647  UNKNOWN_ACTIVITY_TYPE                       0.00      1828
# 10648                CYCLING                       0.00       613
# 10649             IN_VEHICLE                       0.00      3719
# 10650                CYCLING                       0.00      5595
#
#                confidence      startTimestamp        endTimestamp  day  month  \
# 0                  MEDIUM 2020-05-18 18:00:09 2020-05-18 18:16:18   18      5
# 1                    HIGH 2020-05-18 19:34:05 2020-05-18 19:44:14   18      5
# 2                    HIGH 2020-05-19 09:20:20 2020-05-19 10:07:08   19      5
# 3                    HIGH 2020-05-19 13:28:45 2020-05-19 13:49:58   19      5
# 4                  MEDIUM 2020-05-20 07:25:32 2020-05-20 08:14:30   20      5
# ...                   ...                 ...                 ...  ...    ...
# 10646                 LOW 2015-01-17 22:46:19 2015-01-19 10:37:09   19      1
# 10647  UNKNOWN_CONFIDENCE 2015-01-20 16:53:06 2015-01-21 20:26:28   21      1
# 10648                 LOW 2015-01-21 20:26:28 2015-01-21 20:28:28   21      1
# 10649                 LOW 2015-01-27 19:17:14 2015-01-27 21:04:03   27      1
# 10650                 LOW 2015-01-29 19:42:16 2015-01-31 16:56:54   31      1
#
#        year        date   day_name
# 0      2020  2020-05-18     Monday
# 1      2020  2020-05-18     Monday
# 2      2020  2020-05-19    Tuesday
# 3      2020  2020-05-19    Tuesday
# 4      2020  2020-05-20  Wednesday
# ...     ...         ...        ...
# 10646  2015  2015-01-19     Monday
# 10647  2015  2015-01-21  Wednesday
# 10648  2015  2015-01-21  Wednesday
# 10649  2015  2015-01-27    Tuesday
# 10650  2015  2015-01-31   Saturday
#
# [10651 rows x 11 columns]

# %%
onlycycling = df['Activity_Type'] == 'CYCLING'
not_non_or_low_confidence = df['confidence'].isin(['MEDIUM','HIGH'])
year_2023 = df['year'] == 2023
feb_to_may = df['month'].isin([2,3,4,5])

# %%
df = df.loc[onlycycling & not_non_or_low_confidence & year_2023 & feb_to_may].reset_index(drop=True)
df
# Out:
#     Activity_Type  Activity_Type_probability  distance confidence  \
# 0         CYCLING                      87.31      2418       HIGH
# 1         CYCLING                      97.04       946       HIGH
# 2         CYCLING                      99.27      5599       HIGH
# 3         CYCLING                      99.05      5400       HIGH
# 4         CYCLING                      96.38      1015       HIGH
# ..            ...                        ...       ...        ...
# 427       CYCLING                      97.60      1119       HIGH
# 428       CYCLING                      96.41      1140       HIGH
# 429       CYCLING                      93.84       291       HIGH
# 430       CYCLING                      95.16      1606       HIGH
# 431       CYCLING                      94.01      1676       HIGH
#
#          startTimestamp        endTimestamp  day  month  year        date  \
# 0   2023-05-01 06:42:25 2023-05-01 07:04:02    1      5  2023  2023-05-01
# 1   2023-05-01 13:41:49 2023-05-01 13:51:20    1      5  2023  2023-05-01
# 2   2023-05-01 13:59:43 2023-05-01 14:30:28    1      5  2023  2023-05-01
# 3   2023-05-01 15:40:18 2023-05-01 16:15:45    1      5  2023  2023-05-01
# 4   2023-05-01 16:32:35 2023-05-01 16:41:59    1      5  2023  2023-05-01
# ..                  ...                 ...  ...    ...   ...         ...
# 427 2023-03-30 18:11:15 2023-03-30 18:24:21   30      3  2023  2023-03-30
# 428 2023-03-30 19:37:14 2023-03-30 19:47:02   30      3  2023  2023-03-30
# 429 2023-03-30 19:55:04 2023-03-30 19:57:35   30      3  2023  2023-03-30
# 430 2023-03-31 11:47:32 2023-03-31 11:57:20   31      3  2023  2023-03-31
# 431 2023-03-31 12:48:22 2023-03-31 13:01:47   31      3  2023  2023-03-31
#
#      day_name
# 0      Monday
# 1      Monday
# 2      Monday
# 3      Monday
# 4      Monday
# ..        ...
# 427  Thursday
# 428  Thursday
# 429  Thursday
# 430    Friday
# 431    Friday
#
# [432 rows x 11 columns]

# %%
df['distance'] = df['distance']/1000
df
# Out:
#     Activity_Type  Activity_Type_probability  distance confidence  \
# 0         CYCLING                      87.31      2.42       HIGH
# 1         CYCLING                      97.04      0.95       HIGH
# 2         CYCLING                      99.27      5.60       HIGH
# 3         CYCLING                      99.05      5.40       HIGH
# 4         CYCLING                      96.38      1.01       HIGH
# ..            ...                        ...       ...        ...
# 427       CYCLING                      97.60      1.12       HIGH
# 428       CYCLING                      96.41      1.14       HIGH
# 429       CYCLING                      93.84      0.29       HIGH
# 430       CYCLING                      95.16      1.61       HIGH
# 431       CYCLING                      94.01      1.68       HIGH
#
#          startTimestamp        endTimestamp  day  month  year        date  \
# 0   2023-05-01 06:42:25 2023-05-01 07:04:02    1      5  2023  2023-05-01
# 1   2023-05-01 13:41:49 2023-05-01 13:51:20    1      5  2023  2023-05-01
# 2   2023-05-01 13:59:43 2023-05-01 14:30:28    1      5  2023  2023-05-01
# 3   2023-05-01 15:40:18 2023-05-01 16:15:45    1      5  2023  2023-05-01
# 4   2023-05-01 16:32:35 2023-05-01 16:41:59    1      5  2023  2023-05-01
# ..                  ...                 ...  ...    ...   ...         ...
# 427 2023-03-30 18:11:15 2023-03-30 18:24:21   30      3  2023  2023-03-30
# 428 2023-03-30 19:37:14 2023-03-30 19:47:02   30      3  2023  2023-03-30
# 429 2023-03-30 19:55:04 2023-03-30 19:57:35   30      3  2023  2023-03-30
# 430 2023-03-31 11:47:32 2023-03-31 11:57:20   31      3  2023  2023-03-31
# 431 2023-03-31 12:48:22 2023-03-31 13:01:47   31      3  2023  2023-03-31
#
#      day_name
# 0      Monday
# 1      Monday
# 2      Monday
# 3      Monday
# 4      Monday
# ..        ...
# 427  Thursday
# 428  Thursday
# 429  Thursday
# 430    Friday
# 431    Friday
#
# [432 rows x 11 columns]

# %%
daily_metrics = df.groupby(['month','day'])[['distance']].agg('sum')
daily_metrics = daily_metrics.rename({'distance':'Total distance'}, axis = 1)
daily_metrics
# Out:
#            Total distance
# month day
# 2     1              5.73
#       2              6.63
#       3             19.55
#       4              7.87
#       5              1.96
# ...                   ...
# 5     27             6.38
#       28            10.42
#       29            15.39
#       30             0.71
#       31            15.48
#
# [116 rows x 1 columns]

# %%
weekday_analysis = df.groupby('day_name')['distance'].sum()
weekday_analysis
# Out:
# day_name
# Friday      197.33
# Monday      147.61
# Saturday     96.17
# Sunday       89.17
# Thursday    118.47
# Tuesday     135.96
# Wednesday   173.05
# Name: distance, dtype: float64

# %%
df_weekday = df.merge(weekday_analysis, how='inner', on=['day_name'], indicator = True)
df_weekday = df_weekday.groupby('day_name').head(1).reset_index(drop=True)
df_weekday['distance_y'] = df_weekday['distance_y']/17
df_weekday
# Out:
#   Activity_Type  Activity_Type_probability  distance_x confidence  \
# 0       CYCLING                      87.31        2.42       HIGH
# 1       CYCLING                      89.07        2.67       HIGH
# 2       CYCLING                      97.78        4.60       HIGH
# 3       CYCLING                       0.00        0.28       HIGH
# 4       CYCLING                      89.21        0.44       HIGH
# 5       CYCLING                       0.00        1.23       HIGH
# 6       CYCLING                      95.46        1.09       HIGH
#
#        startTimestamp        endTimestamp  day  month  year        date  \
# 0 2023-05-01 06:42:25 2023-05-01 07:04:02    1      5  2023  2023-05-01
# 1 2023-05-02 14:28:33 2023-05-02 14:52:03    2      5  2023  2023-05-02
# 2 2023-05-03 14:20:45 2023-05-03 14:45:51    3      5  2023  2023-05-03
# 3 2023-05-04 09:19:10 2023-05-04 09:21:12    4      5  2023  2023-05-04
# 4 2023-05-05 08:36:23 2023-05-05 08:40:31    5      5  2023  2023-05-05
# 5 2023-05-06 07:54:11 2023-05-06 08:07:25    6      5  2023  2023-05-06
# 6 2023-05-07 07:53:50 2023-05-07 08:06:00    7      5  2023  2023-05-07
#
#     day_name  distance_y _merge
# 0     Monday        8.68   both
# 1    Tuesday        8.00   both
# 2  Wednesday       10.18   both
# 3   Thursday        6.97   both
# 4     Friday       11.61   both
# 5   Saturday        5.66   both
# 6     Sunday        5.25   both

# %%
df = df.merge(daily_metrics, how='inner', on=['month','day'], indicator = True)

# %%
df
# Out:
#     Activity_Type  Activity_Type_probability  distance confidence  \
# 0         CYCLING                      87.31      2.42       HIGH
# 1         CYCLING                      97.04      0.95       HIGH
# 2         CYCLING                      99.27      5.60       HIGH
# 3         CYCLING                      99.05      5.40       HIGH
# 4         CYCLING                      96.38      1.01       HIGH
# ..            ...                        ...       ...        ...
# 427       CYCLING                      97.60      1.12       HIGH
# 428       CYCLING                      96.41      1.14       HIGH
# 429       CYCLING                      93.84      0.29       HIGH
# 430       CYCLING                      95.16      1.61       HIGH
# 431       CYCLING                      94.01      1.68       HIGH
#
#          startTimestamp        endTimestamp  day  month  year        date  \
# 0   2023-05-01 06:42:25 2023-05-01 07:04:02    1      5  2023  2023-05-01
# 1   2023-05-01 13:41:49 2023-05-01 13:51:20    1      5  2023  2023-05-01
# 2   2023-05-01 13:59:43 2023-05-01 14:30:28    1      5  2023  2023-05-01
# 3   2023-05-01 15:40:18 2023-05-01 16:15:45    1      5  2023  2023-05-01
# 4   2023-05-01 16:32:35 2023-05-01 16:41:59    1      5  2023  2023-05-01
# ..                  ...                 ...  ...    ...   ...         ...
# 427 2023-03-30 18:11:15 2023-03-30 18:24:21   30      3  2023  2023-03-30
# 428 2023-03-30 19:37:14 2023-03-30 19:47:02   30      3  2023  2023-03-30
# 429 2023-03-30 19:55:04 2023-03-30 19:57:35   30      3  2023  2023-03-30
# 430 2023-03-31 11:47:32 2023-03-31 11:57:20   31      3  2023  2023-03-31
# 431 2023-03-31 12:48:22 2023-03-31 13:01:47   31      3  2023  2023-03-31
#
#      day_name  Total distance _merge
# 0      Monday           17.41   both
# 1      Monday           17.41   both
# 2      Monday           17.41   both
# 3      Monday           17.41   both
# 4      Monday           17.41   both
# ..        ...             ...    ...
# 427  Thursday            2.55   both
# 428  Thursday            2.55   both
# 429  Thursday            2.55   both
# 430    Friday            3.28   both
# 431    Friday            3.28   both
#
# [432 rows x 13 columns]

# %%
df = df.groupby(['month','day']).head(1).reset_index(drop=True)
df
# Out:
#     Activity_Type  Activity_Type_probability  distance confidence  \
# 0         CYCLING                      87.31      2.42       HIGH
# 1         CYCLING                      89.07      2.67       HIGH
# 2         CYCLING                      97.78      4.60       HIGH
# 3         CYCLING                       0.00      0.28       HIGH
# 4         CYCLING                      89.21      0.44       HIGH
# ..            ...                        ...       ...        ...
# 111       CYCLING                      98.19      4.59       HIGH
# 112       CYCLING                      93.62      1.19       HIGH
# 113       CYCLING                      78.83      0.29       HIGH
# 114       CYCLING                      97.60      1.12       HIGH
# 115       CYCLING                      95.16      1.61       HIGH
#
#          startTimestamp        endTimestamp  day  month  year        date  \
# 0   2023-05-01 06:42:25 2023-05-01 07:04:02    1      5  2023  2023-05-01
# 1   2023-05-02 14:28:33 2023-05-02 14:52:03    2      5  2023  2023-05-02
# 2   2023-05-03 14:20:45 2023-05-03 14:45:51    3      5  2023  2023-05-03
# 3   2023-05-04 09:19:10 2023-05-04 09:21:12    4      5  2023  2023-05-04
# 4   2023-05-05 08:36:23 2023-05-05 08:40:31    5      5  2023  2023-05-05
# ..                  ...                 ...  ...    ...   ...         ...
# 111 2023-03-27 14:15:31 2023-03-27 14:41:48   27      3  2023  2023-03-27
# 112 2023-03-28 10:07:31 2023-03-28 10:13:32   28      3  2023  2023-03-28
# 113 2023-03-29 09:42:04 2023-03-29 09:45:33   29      3  2023  2023-03-29
# 114 2023-03-30 18:11:15 2023-03-30 18:24:21   30      3  2023  2023-03-30
# 115 2023-03-31 11:47:32 2023-03-31 11:57:20   31      3  2023  2023-03-31
#
#       day_name  Total distance _merge
# 0       Monday           17.41   both
# 1      Tuesday            4.82   both
# 2    Wednesday            9.44   both
# 3     Thursday            9.34   both
# 4       Friday            1.31   both
# ..         ...             ...    ...
# 111     Monday            9.58   both
# 112    Tuesday           12.05   both
# 113  Wednesday           12.46   both
# 114   Thursday            2.55   both
# 115     Friday            3.28   both
#
# [116 rows x 13 columns]

# %%
pd.options.display.float_format = "{:.2f}".format

df['Total distance'].agg('mean')
# Out:
# 8.256577586206896

# %%
df
# Out:
#     Activity_Type  Activity_Type_probability  distance confidence  \
# 0         CYCLING                      87.31      2.42       HIGH
# 1         CYCLING                      89.07      2.67       HIGH
# 2         CYCLING                      97.78      4.60       HIGH
# 3         CYCLING                       0.00      0.28       HIGH
# 4         CYCLING                      89.21      0.44       HIGH
# ..            ...                        ...       ...        ...
# 111       CYCLING                      98.19      4.59       HIGH
# 112       CYCLING                      93.62      1.19       HIGH
# 113       CYCLING                      78.83      0.29       HIGH
# 114       CYCLING                      97.60      1.12       HIGH
# 115       CYCLING                      95.16      1.61       HIGH
#
#          startTimestamp        endTimestamp  day  month  year        date  \
# 0   2023-05-01 06:42:25 2023-05-01 07:04:02    1      5  2023  2023-05-01
# 1   2023-05-02 14:28:33 2023-05-02 14:52:03    2      5  2023  2023-05-02
# 2   2023-05-03 14:20:45 2023-05-03 14:45:51    3      5  2023  2023-05-03
# 3   2023-05-04 09:19:10 2023-05-04 09:21:12    4      5  2023  2023-05-04
# 4   2023-05-05 08:36:23 2023-05-05 08:40:31    5      5  2023  2023-05-05
# ..                  ...                 ...  ...    ...   ...         ...
# 111 2023-03-27 14:15:31 2023-03-27 14:41:48   27      3  2023  2023-03-27
# 112 2023-03-28 10:07:31 2023-03-28 10:13:32   28      3  2023  2023-03-28
# 113 2023-03-29 09:42:04 2023-03-29 09:45:33   29      3  2023  2023-03-29
# 114 2023-03-30 18:11:15 2023-03-30 18:24:21   30      3  2023  2023-03-30
# 115 2023-03-31 11:47:32 2023-03-31 11:57:20   31      3  2023  2023-03-31
#
#       day_name  Total distance _merge
# 0       Monday           17.41   both
# 1      Tuesday            4.82   both
# 2    Wednesday            9.44   both
# 3     Thursday            9.34   both
# 4       Friday            1.31   both
# ..         ...             ...    ...
# 111     Monday            9.58   both
# 112    Tuesday           12.05   both
# 113  Wednesday           12.46   both
# 114   Thursday            2.55   both
# 115     Friday            3.28   both
#
# [116 rows x 13 columns]
